# %%
import requests
import json
import os

def transform(esDoc):
    pass


# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
    whatToAnalyze = ''
    if field is not None:
        whatToAnalyze = "field=%s" % field
    elif analyzer is not None:
        whatToAnalyze = "analyzer=%s" % analyzer
    resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
                        data=text)
    print resp.text
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    headers = {'Content-type': 'application/json', 'Accept': 'application/json'}    
    url = 'http://localhost:9200/tmdb/_search'
    httpResp = requests.get(url, data=json.dumps(query),headers=headers)
    if httpResp.status_code != 200:
        print "Search Failed <%s>" % httpResp.status_code
        print "%s" % httpResp.text
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s\t%s\t%s" % (idx + 1, hit['_score'], 
                                      hit['_source']['title'], 
                                      hit['_source']['vote_average'],
                                      hit['_source']['release_date'])
            if verbose:
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "DIRS %s" % directorNames
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        httpResp = requests.get('http://localhost:9200' + 
                    '/tmdb/movie/_validate/query?explain',
                     data=json.dumps({'query': query['query']}),headers=headers)
        print json.loads(httpResp.text)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    headers = {'Content-type': 'application/json', 'Accept': 'application/json'}    

    # Destroy any existing index (equiv to SQL "drop table")
    resp = requests.delete("http://localhost:9200/tmdb")
    print "Delete TMDB Index <%s>" % resp.status_code
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = requests.put("http://localhost:9200/tmdb", data=json.dumps(settings),headers=headers)
    print "Create TMDB Index <%s>" % resp.status_code
    if resp.status_code != 200:
        print resp.text
    
    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    lastMovie = None
    for id, movie in movieDict.iteritems():
        addCmd = {"index": {"_index": "tmdb",  "_id": movie["id"]}}
        esDoc  = movie
        transform(esDoc)
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(esDoc) + "\n"
        lastMovie = movie
    print json.dumps(lastMovie, indent=True)
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies,headers=headers)
    print "Bulk Index into TMDB Index <%s>" % resp.status_code


def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass       
    return movieDict

# %% [markdown]
# ## Index to ES, Chapter 5 Settings

# %%
movieDict = extract([])

analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "standard",
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}

            
mappingSettings = {
        'properties': {
            # Some bug means I have to be explicit about analyzer (ie default analyzer)
            # doesn't apply
            "overview": {
                'type': 'string',
                 'analyzer': 'english',

            },
            "title": {
                'type': 'string',
                 'analyzer': 'english',

            },
            "cast": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams",
                            #"norms" : {
                            #   "enabled" : False
                            #}
                        }     
                      }
                   }
                   
               }
            },
            "directors": {
               'properties': {
                  'name': {
                      'type': 'string',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "string",
                            "analyzer": "english_bigrams",
                            #"norms" : {
                            #   "enabled" : False
                            #}
                        }                       
                      },
                 
                   }
                   
               }
            }            
        }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <400>
# {"error":{"root_cause":[{"type":"illegal_argument_exception","reason":"The [standard] token filter has been removed."}],"type":"illegal_argument_exception","reason":"The [standard] token filter has been removed."},"status":400}
# Indexing 3051 movies
# {
#  "poster_path": "/xYLmHi80zIlu3JDfJYfd1JY0Xl7.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 300400432,
#  "overview": "Col. Troutman recruits ex-Green Beret John Rambo for a highly secret and dangerous mission. Teamed with freedom fighter Co Bao, Rambo goes deep into Vietnam to rescue POWs. Deserted by his own team, he's left in a hostile jungle to fight for his life, avenge the death of a woman and bring corrupt officials to justice.",
#  "title_exact_match": "SENTINEL_BEGIN Rambo: First Blood Part II SENTINEL_END",
#  "video": false,
#  "id": 1369,
#  "genres": [
#   {
#    "id": 28,
#    "name": "Action"
#   },
#   {
#    "id": 12,
#    "name": "Adventure"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 53,
#    "name": "Thriller"
#   },
#   {
#    "id": 10752,
#    "name": "War"
#   }
#  ],
#  "title": "Rambo: First Blood Part II",
#  "tagline": "What most people call hell, he calls home.",
#  "vote_count": 224,
#  "homepage": "",
#  "belongs_to_collection": {
#   "poster_path": "/a61qhaM73Acotl98fAxj6ey7YzE.jpg",
#   "backdrop_path": "/Yt2ZxbJv2HM842B6FNMr59Vhyb.jpg",
#   "name": "Rambo Collection",
#   "id": 5039
#  },
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   },
#   {
#    "iso_639_1": "vi",
#    "name": "Ti\u1ebfng Vi\u1ec7t"
#   }
#  ],
#  "imdb_id": "tt0089880",
#  "adult": false,
#  "backdrop_path": "/dy5ThWXUuEHH60liT8oVSDqkSGB.jpg",
#  "production_companies": [
#   {
#    "name": "TriStar Pictures",
#    "id": 559
#   },
#   {
#    "name": "Carolco Pictures",
#    "id": 14723
#   }
#  ],
#  "release_date": "1985-05-21",
#  "popularity": 1.09210705984778,
#  "original_title": "Rambo: First Blood Part II",
#  "budget": 44000000,
#  "cast": [
#   {
#    "name": "Sylvester Stallone",
#    "character": "John J. Rambo",
#    "order": 0,
#    "cast_id": 27,
#    "credit_id": "52fe42f0c3a36847f802e327",
#    "profile_path": "/gnmwOa46C2TP35N7ARSzboTdx2u.jpg",
#    "id": 16483
#   },
#   {
#    "name": "Richard Crenna",
#    "character": "Col. Samuel Trautman",
#    "order": 1,
#    "cast_id": 28,
#    "credit_id": "52fe42f0c3a36847f802e32b",
#    "profile_path": "/fUCwfoN3JurrzltOyJT9rDNZRbV.jpg",
#    "id": 16554
#   },
#   {
#    "name": "Charles Napier",
#    "character": "Marshall Murdock",
#    "order": 2,
#    "cast_id": 29,
#    "credit_id": "52fe42f0c3a36847f802e32f",
#    "profile_path": "/hZ3bCBxnHc7Zvrm3Rt2CPgXSLLT.jpg",
#    "id": 16119
#   },
#   {
#    "name": "Steven Berkoff",
#    "character": "Lt. Col. Podovsky",
#    "order": 3,
#    "cast_id": 30,
#    "credit_id": "52fe42f0c3a36847f802e333",
#    "profile_path": "/jiYMK9prj46Qe4gmbKtBDE6YlSr.jpg",
#    "id": 782
#   },
#   {
#    "name": "Julia Nickson",
#    "character": "Co Bao",
#    "order": 4,
#    "cast_id": 31,
#    "credit_id": "52fe42f0c3a36847f802e337",
#    "profile_path": "/zQzqbbfixENqr2NLp92EOtL7POQ.jpg",
#    "id": 16578
#   },
#   {
#    "name": "George Cheung",
#    "character": "Capt Vinh",
#    "order": 5,
#    "cast_id": 32,
#    "credit_id": "52fe42f0c3a36847f802e33b",
#    "profile_path": null,
#    "id": 16580
#   },
#   {
#    "name": "Andy Wood",
#    "character": "Banks",
#    "order": 6,
#    "cast_id": 33,
#    "credit_id": "52fe42f0c3a36847f802e33f",
#    "profile_path": null,
#    "id": 16581
#   },
#   {
#    "name": "William Ghent",
#    "character": "Capt. Vinh",
#    "order": 7,
#    "cast_id": 34,
#    "credit_id": "52fe42f0c3a36847f802e343",
#    "profile_path": null,
#    "id": 16582
#   },
#   {
#    "name": "Voyo Goric",
#    "character": "Sgt. Yushin",
#    "order": 8,
#    "cast_id": 35,
#    "credit_id": "52fe42f0c3a36847f802e347",
#    "profile_path": null,
#    "id": 16583
#   },
#   {
#    "name": "Dana Lee",
#    "character": "Gunboat captain",
#    "order": 9,
#    "cast_id": 36,
#    "credit_id": "52fe42f0c3a36847f802e34b",
#    "profile_path": null,
#    "id": 16584
#   },
#   {
#    "name": "Baoan Coleman",
#    "character": "Gunboat captain II",
#    "order": 10,
#    "cast_id": 37,
#    "credit_id": "52fe42f0c3a36847f802e34f",
#    "profile_path": null,
#    "id": 16585
#   },
#   {
#    "name": "Steve Williams",
#    "character": "Lifer",
#    "order": 11,
#    "cast_id": 38,
#    "credit_id": "52fe42f0c3a36847f802e353",
#    "profile_path": null,
#    "id": 16586
#   },
#   {
#    "name": "Don Collins",
#    "character": "POW #1",
#    "order": 12,
#    "cast_id": 39,
#    "credit_id": "52fe42f0c3a36847f802e357",
#    "profile_path": null,
#    "id": 16587
#   },
#   {
#    "name": "Christopher Grant",
#    "character": "POW #2",
#    "order": 13,
#    "cast_id": 40,
#    "credit_id": "52fe42f0c3a36847f802e35b",
#    "profile_path": null,
#    "id": 16588
#   },
#   {
#    "name": "Martin Kove",
#    "character": "Ericson",
#    "order": 14,
#    "cast_id": 41,
#    "credit_id": "52fe42f0c3a36847f802e35f",
#    "profile_path": "/rQtB405GPPgWNL2EUL9mOx4FTb9.jpg",
#    "id": 56117
#   }
#  ],
#  "directors": [
#   {
#    "name": "George P. Cosmatos",
#    "credit_id": "52fe42efc3a36847f802e28d",
#    "job": "Director",
#    "department": "Directing",
#    "profile_path": "/6DIKPjnDvr7oHgTPHTXM5te45Qt.jpg",
#    "id": 16566
#   }
#  ],
#  "names_exact_match": [
#   "SENTINEL_BEGIN Sylvester Stallone SENTINEL_END",
#   "SENTINEL_BEGIN Richard Crenna SENTINEL_END",
#   "SENTINEL_BEGIN Charles Napier SENTINEL_END",
#   "SENTINEL_BEGIN Steven Berkoff SENTINEL_END",
#   "SENTINEL_BEGIN Julia Nickson SENTINEL_END",
#   "SENTINEL_BEGIN George Cheung SENTINEL_END",
#   "SENTINEL_BEGIN Andy Wood SENTINEL_END",
#   "SENTINEL_BEGIN William Ghent SENTINEL_END",
#   "SENTINEL_BEGIN Voyo Goric SENTINEL_END",
#   "SENTINEL_BEGIN Dana Lee SENTINEL_END",
#   "SENTINEL_BEGIN Baoan Coleman SENTINEL_END",
#   "SENTINEL_BEGIN Steve Williams SENTINEL_END",
#   "SENTINEL_BEGIN Don Collins SENTINEL_END",
#   "SENTINEL_BEGIN Christopher Grant SENTINEL_END",
#   "SENTINEL_BEGIN Martin Kove SENTINEL_END",
#   "SENTINEL_BEGIN George P. Cosmatos SENTINEL_END"
#  ],
#  "vote_average": 6.2,
#  "runtime": 96
# }
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # Last Query from Chapter 5

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'bool': {
            'should': [ 
                {
                   'multi_match': { 
                      'query': usersSearch,  #User's query
                      'fields': ['directors.name.bigramed', #B 
				      'cast.name.bigramed'],
                      'type': 'cross_fields'
                      }
                 },
                {
                   'multi_match': {
                     'query': usersSearch,  #User's query
                     'fields': ['overview', 'title', #C
  'directors.name', 'cast.name'],
                     'type': 'cross_fields'                                
                   }
                },
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	23.395248		Star Trek: Generations	6.5	1994-11-17
# 2	16.90487		Star Trek: Nemesis	6.3	2002-12-12
# 3	15.94338		Star Trek: Insurrection	6.3	1998-12-10
# 4	14.725054		Star Trek: The Motion Picture	6.0	1979-12-06
# 5	14.690414		Star Trek V: The Final Frontier	5.4	1989-06-09

# %% [markdown]
# # 7.2.1, Listing 1 Base Query

# %%
usersSearch = 'william shatner patrick stewart'
query = {
    'query': {
        'multi_match': {
           'query': usersSearch,  #User's query
            'fields': ['overview', 'title', #C
                       'directors.name', 'cast.name'],
            'type': 'cross_fields'                                
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	13.943897		Star Trek: Generations	6.5	1994-11-17
# 2	10.299481		Showtime	5.3	2002-03-14
# 3	10.00054		Osmosis Jones	5.4	2001-08-07
# 4	9.688064		The Wild	5.0	2006-04-13
# 5	8.845243		Star Trek II: The Wrath of Khan	7.1	1982-06-03

# %% [markdown]
# # 7.2.3, Listing 2 Boosting with An Additional Boolean Clause

# %%
usersSearch = 'william shatner patrick stewart'
query = {
    'query': {
        'bool': {
            'should': [
            {'multi_match': { #A
               'query': usersSearch,  #User's query
                'fields': ['overview', 'title', #C
                           'directors.name', 'cast.name'],
                'type': 'cross_fields'                                
             }},
            { #B
               'match_phrase': {
                    'title': {
                        'query': 'star trek',
                    }
                }
            }
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	24.152754		Star Trek: Generations	6.5	1994-11-17
# 2	18.148397		Star Trek: Nemesis	6.3	2002-12-12
# 3	17.186909		Star Trek: Insurrection	6.3	1998-12-10
# 4	15.692402		Star Trek: The Motion Picture	6.0	1979-12-06
# 5	15.6496525		Star Trek: First Contact	6.9	1996-11-21

# %% [markdown]
# # 7.2.3, Adjusted Boost Weight on Boolean Query (no listing no, modification of above listing)

# %%
usersSearch = 'william shatner patrick stewart'
query = {
    'query': {
        'bool': {
            'should': [
            {'multi_match': { #A
               'query': usersSearch,  #User's query
                'fields': ['overview', 'title', #C
                           'directors.name', 'cast.name'],
                'type': 'cross_fields'                                
             }},
            { #B
               'match_phrase': {
                    'title': {
                        'query': 'star trek',
                        'boost': 0.1
                    }
                }
            }
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	14.964783		Star Trek: Generations	6.5	1994-11-17
# 2	10.299481		Showtime	5.3	2002-03-14
# 3	10.00054		Osmosis Jones	5.4	2001-08-07
# 4	9.688064		The Wild	5.0	2006-04-13
# 5	9.495074		Star Trek II: The Wrath of Khan	7.1	1982-06-03

# %% [markdown]
# # 7.2.5, Listing 3 -- Multiplicative Boosting on Title Star Trek match

# %%
usersSearch = 'william shatner patrick stewart'
query = {
    'query': {
        'function_score': {
            'query': {
                 'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'                                
                 }
             },
             'functions': [
                {
                     'weight': 2.5,
                     'filter': {
                             'match_phrase': {
                                    'title': 'star trek'
                            }
                     }
                 }
            ]
        }
    },
    'size': 50,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	34.85974		Star Trek: Generations	6.5	1994-11-17
# 2	22.11311		Star Trek II: The Wrath of Khan	7.1	1982-06-03
# 3	21.033188		Star Trek V: The Final Frontier	5.4	1989-06-09
# 4	20.531837		Star Trek IV: The Voyage Home	6.7	1986-11-25
# 5	19.848852		Star Trek: Nemesis	6.3	2002-12-12
# 6	19.823082		Star Trek III: The Search for Spock	6.3	1984-05-31
# 7	19.37715		Star Trek: The Motion Picture	6.0	1979-12-06
# 8	17.595911		Star Trek VI: The Undiscovered Country	6.6	1991-12-05
# 9	17.44513		Star Trek: Insurrection	6.3	1998-12-10
# 10	16.790169		Star Trek: First Contact	6.9	1996-11-21
# 11	10.299481		Showtime	5.3	2002-03-14
# 12	10.00054		Osmosis Jones	5.4	2001-08-07
# 13	9.688064		The Wild	5.0	2006-04-13
# 14	8.834773		Bill & Ted's Bogus Journey	5.8	1991-07-19
# 15	8.413275		Miss Congeniality 2: Armed and Fabulous	5.3	2005-03-11
# 16	8.116009		Over the Hedge	6.2	2006-04-22
# 17	7.9292326		Miss Congeniality	6.0	2000-12-14
# 18	7.7939878		X2: X-Men United	6.5	2003-04-27
# 19	7.66465		Escape from Planet Earth	5.9	2013-02-14
# 20	7.164365		Vertigo	7.4	1958-05-28
# 21	7.0383644		Fanboys	6.3	2009-02-06
# 22	6.820343		The Collector	6.4	2009-07-09
# 23	6.5520735		Gnomeo & Juliet	5.9	2011-01-13
# 24	6.5520735		Excalibur	6.7	1981-04-10
# 25	6.470996		X-Men: Days of Future Past	7.7	2014-05-23
# 26	6.3849235		One Flew Over the Cuckoo's Nest	7.8	1975-11-18
# 27	6.320569		Panic Room	6.3	2002-03-29
# 28	6.3038015		Into the Wild	7.6	2007-09-20
# 29	6.246994		Conspiracy Theory	6.2	1997-08-07
# 30	6.1570415		Flatliners	6.5	1990-08-09
# 31	6.1048656		Robin Hood: Men in Tights	6.2	1993-07-28
# 32	6.0169597		The Collection	6.0	2012-09-21
# 33	5.969061		The Wolverine	6.4	2013-07-25
# 34	5.88311		Singin' in the Rain	7.1	1952-04-10
# 35	5.8391657		X-Men	6.5	2000-07-14
# 36	5.8022084		Jeepers Creepers	6.1	2001-07-01
# 37	5.7148046		Dune	6.5	1984-12-14
# 38	5.6146135		Ted	6.3	2012-06-29
# 39	5.5956297		Save the Last Dance	6.4	2001-01-12
# 40	5.5956297		TMNT	6.0	2007-03-22
# 41	5.5886006		Dark Skies	6.0	2013-02-21
# 42	5.565819		Red Dawn	6.7	1984-08-10
# 43	5.4813232		The Prince of Egypt	6.7	1998-12-15
# 44	5.266173		A Time to Kill	6.8	1996-07-24
# 45	5.1648083		X-Men: The Last Stand	6.1	2006-05-26
# 46	5.1069517		Enchanted	6.3	2007-11-20
# 47	5.090439		Interstellar	8.4	2014-11-05
# 48	5.08529		Last Man Standing	5.9	1996-09-20
# 49	5.047504		Phantom	5.7	2013-01-03
# 50	4.989424		The Outsiders	6.3	1983-03-25

# %% [markdown]
# # 7.3, Listing 4 -- Using a Filter Instead of A Boost

# %%
usersSearch = 'william shatner patrick stewart'
query = {
    'query': {
        'bool': {
          'should': [
            {    'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'                                
                 }
            }],
          'filter': [{
                'match_phrase': {
                    'title': 'star trek'
                }
          }]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	13.943897		Star Trek: Generations	6.5	1994-11-17
# 2	8.845243		Star Trek II: The Wrath of Khan	7.1	1982-06-03
# 3	8.413275		Star Trek V: The Final Frontier	5.4	1989-06-09
# 4	8.212735		Star Trek IV: The Voyage Home	6.7	1986-11-25
# 5	7.939541		Star Trek: Nemesis	6.3	2002-12-12

# %% [markdown]
# # 7.4.2, Listings 5&7 Sentinel Tokens (includes exact name matching)

# %%
SENTINEL_BEGIN = 'SENTINEL_BEGIN'
SENTINEL_END = 'SENTINEL_END'
def transform(esDoc):    
    esDoc['title_exact_match'] = SENTINEL_BEGIN + ' ' + esDoc['title'] + ' ' + SENTINEL_END
    esDoc['names_exact_match'] = []
    for person in esDoc['cast'] + esDoc['directors']:
        esDoc['names_exact_match'].append(SENTINEL_BEGIN + ' ' + person['name'] + ' ' + SENTINEL_END)
        


        
reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <400>
# {"error":{"root_cause":[{"type":"illegal_argument_exception","reason":"The [standard] token filter has been removed."}],"type":"illegal_argument_exception","reason":"The [standard] token filter has been removed."},"status":400}
# Indexing 3051 movies
# {
#  "poster_path": "/xYLmHi80zIlu3JDfJYfd1JY0Xl7.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 300400432,
#  "overview": "Col. Troutman recruits ex-Green Beret John Rambo for a highly secret and dangerous mission. Teamed with freedom fighter Co Bao, Rambo goes deep into Vietnam to rescue POWs. Deserted by his own team, he's left in a hostile jungle to fight for his life, avenge the death of a woman and bring corrupt officials to justice.",
#  "title_exact_match": "SENTINEL_BEGIN Rambo: First Blood Part II SENTINEL_END",
#  "video": false,
#  "id": 1369,
#  "genres": [
#   {
#    "id": 28,
#    "name": "Action"
#   },
#   {
#    "id": 12,
#    "name": "Adventure"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 53,
#    "name": "Thriller"
#   },
#   {
#    "id": 10752,
#    "name": "War"
#   }
#  ],
#  "title": "Rambo: First Blood Part II",
#  "tagline": "What most people call hell, he calls home.",
#  "vote_count": 224,
#  "homepage": "",
#  "belongs_to_collection": {
#   "poster_path": "/a61qhaM73Acotl98fAxj6ey7YzE.jpg",
#   "backdrop_path": "/Yt2ZxbJv2HM842B6FNMr59Vhyb.jpg",
#   "name": "Rambo Collection",
#   "id": 5039
#  },
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   },
#   {
#    "iso_639_1": "vi",
#    "name": "Ti\u1ebfng Vi\u1ec7t"
#   }
#  ],
#  "imdb_id": "tt0089880",
#  "adult": false,
#  "backdrop_path": "/dy5ThWXUuEHH60liT8oVSDqkSGB.jpg",
#  "production_companies": [
#   {
#    "name": "TriStar Pictures",
#    "id": 559
#   },
#   {
#    "name": "Carolco Pictures",
#    "id": 14723
#   }
#  ],
#  "release_date": "1985-05-21",
#  "popularity": 1.09210705984778,
#  "original_title": "Rambo: First Blood Part II",
#  "budget": 44000000,
#  "cast": [
#   {
#    "name": "Sylvester Stallone",
#    "character": "John J. Rambo",
#    "order": 0,
#    "cast_id": 27,
#    "credit_id": "52fe42f0c3a36847f802e327",
#    "profile_path": "/gnmwOa46C2TP35N7ARSzboTdx2u.jpg",
#    "id": 16483
#   },
#   {
#    "name": "Richard Crenna",
#    "character": "Col. Samuel Trautman",
#    "order": 1,
#    "cast_id": 28,
#    "credit_id": "52fe42f0c3a36847f802e32b",
#    "profile_path": "/fUCwfoN3JurrzltOyJT9rDNZRbV.jpg",
#    "id": 16554
#   },
#   {
#    "name": "Charles Napier",
#    "character": "Marshall Murdock",
#    "order": 2,
#    "cast_id": 29,
#    "credit_id": "52fe42f0c3a36847f802e32f",
#    "profile_path": "/hZ3bCBxnHc7Zvrm3Rt2CPgXSLLT.jpg",
#    "id": 16119
#   },
#   {
#    "name": "Steven Berkoff",
#    "character": "Lt. Col. Podovsky",
#    "order": 3,
#    "cast_id": 30,
#    "credit_id": "52fe42f0c3a36847f802e333",
#    "profile_path": "/jiYMK9prj46Qe4gmbKtBDE6YlSr.jpg",
#    "id": 782
#   },
#   {
#    "name": "Julia Nickson",
#    "character": "Co Bao",
#    "order": 4,
#    "cast_id": 31,
#    "credit_id": "52fe42f0c3a36847f802e337",
#    "profile_path": "/zQzqbbfixENqr2NLp92EOtL7POQ.jpg",
#    "id": 16578
#   },
#   {
#    "name": "George Cheung",
#    "character": "Capt Vinh",
#    "order": 5,
#    "cast_id": 32,
#    "credit_id": "52fe42f0c3a36847f802e33b",
#    "profile_path": null,
#    "id": 16580
#   },
#   {
#    "name": "Andy Wood",
#    "character": "Banks",
#    "order": 6,
#    "cast_id": 33,
#    "credit_id": "52fe42f0c3a36847f802e33f",
#    "profile_path": null,
#    "id": 16581
#   },
#   {
#    "name": "William Ghent",
#    "character": "Capt. Vinh",
#    "order": 7,
#    "cast_id": 34,
#    "credit_id": "52fe42f0c3a36847f802e343",
#    "profile_path": null,
#    "id": 16582
#   },
#   {
#    "name": "Voyo Goric",
#    "character": "Sgt. Yushin",
#    "order": 8,
#    "cast_id": 35,
#    "credit_id": "52fe42f0c3a36847f802e347",
#    "profile_path": null,
#    "id": 16583
#   },
#   {
#    "name": "Dana Lee",
#    "character": "Gunboat captain",
#    "order": 9,
#    "cast_id": 36,
#    "credit_id": "52fe42f0c3a36847f802e34b",
#    "profile_path": null,
#    "id": 16584
#   },
#   {
#    "name": "Baoan Coleman",
#    "character": "Gunboat captain II",
#    "order": 10,
#    "cast_id": 37,
#    "credit_id": "52fe42f0c3a36847f802e34f",
#    "profile_path": null,
#    "id": 16585
#   },
#   {
#    "name": "Steve Williams",
#    "character": "Lifer",
#    "order": 11,
#    "cast_id": 38,
#    "credit_id": "52fe42f0c3a36847f802e353",
#    "profile_path": null,
#    "id": 16586
#   },
#   {
#    "name": "Don Collins",
#    "character": "POW #1",
#    "order": 12,
#    "cast_id": 39,
#    "credit_id": "52fe42f0c3a36847f802e357",
#    "profile_path": null,
#    "id": 16587
#   },
#   {
#    "name": "Christopher Grant",
#    "character": "POW #2",
#    "order": 13,
#    "cast_id": 40,
#    "credit_id": "52fe42f0c3a36847f802e35b",
#    "profile_path": null,
#    "id": 16588
#   },
#   {
#    "name": "Martin Kove",
#    "character": "Ericson",
#    "order": 14,
#    "cast_id": 41,
#    "credit_id": "52fe42f0c3a36847f802e35f",
#    "profile_path": "/rQtB405GPPgWNL2EUL9mOx4FTb9.jpg",
#    "id": 56117
#   }
#  ],
#  "directors": [
#   {
#    "name": "George P. Cosmatos",
#    "credit_id": "52fe42efc3a36847f802e28d",
#    "job": "Director",
#    "department": "Directing",
#    "profile_path": "/6DIKPjnDvr7oHgTPHTXM5te45Qt.jpg",
#    "id": 16566
#   }
#  ],
#  "names_exact_match": [
#   "SENTINEL_BEGIN Sylvester Stallone SENTINEL_END",
#   "SENTINEL_BEGIN Richard Crenna SENTINEL_END",
#   "SENTINEL_BEGIN Charles Napier SENTINEL_END",
#   "SENTINEL_BEGIN Steven Berkoff SENTINEL_END",
#   "SENTINEL_BEGIN Julia Nickson SENTINEL_END",
#   "SENTINEL_BEGIN George Cheung SENTINEL_END",
#   "SENTINEL_BEGIN Andy Wood SENTINEL_END",
#   "SENTINEL_BEGIN William Ghent SENTINEL_END",
#   "SENTINEL_BEGIN Voyo Goric SENTINEL_END",
#   "SENTINEL_BEGIN Dana Lee SENTINEL_END",
#   "SENTINEL_BEGIN Baoan Coleman SENTINEL_END",
#   "SENTINEL_BEGIN Steve Williams SENTINEL_END",
#   "SENTINEL_BEGIN Don Collins SENTINEL_END",
#   "SENTINEL_BEGIN Christopher Grant SENTINEL_END",
#   "SENTINEL_BEGIN Martin Kove SENTINEL_END",
#   "SENTINEL_BEGIN George P. Cosmatos SENTINEL_END"
#  ],
#  "vote_average": 6.2,
#  "runtime": 96
# }
# Bulk Index into TMDB Index <200>

# %% [markdown]
# # 7.4.2, Listing 6 -- Testing Exact Title Matching

# %%
usersSearch = 'star trek'
query = {
    'query': {
        'match_phrase': {
            'title_exact_match': {
                'query': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END,
            }
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	11.299829		Star Trek	7.3	2009-05-07

# %% [markdown]
# # 7.4.3, Listing 8 Boolean Boost on Exact Title Matching

# %%
usersSearch = 'good will hunting'
query = {
    'query': {
        'bool': {
            'should': [
                {'match_phrase': {
                    'title_exact_match': {
                        'query': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END,
                        'boost': 1000,
                    }          
                }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'                                
                 }},
                
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	19248.902		Good Will Hunting	7.4	1997-12-05
# 2	7.298579		Locke	6.7	2014-04-18
# 3	7.206407		Grease	6.6	1978-07-07
# 4	6.9023466		Beautiful Creatures	5.6	2013-02-15
# 5	6.902122		Red Dawn	6.7	1984-08-10

# %% [markdown]
# ## No Listing -- Adding a query mentions name boost

# %% [markdown]
# ### First Attempt, search bigramed fields without modification

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'bool': {
            'disable_coord': True,
            'should': [
                {'match_phrase': {
                    'title_exact_match': {
                        'query': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END,
                        'boost': 1000,
                    }          
                }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'
                }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['directors.name.bigramed', 'cast.name.bigramed'],
                    'type': 'cross_fields',
                   'boost': 100
                 }}
                
            ]
        }
    },
    'size': 20,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.010597555		Star Trek: Insurrection	6.3	1998-12-10
# 2	0.010597555		Star Trek: First Contact	6.9	1996-11-21
# 3	0.009586617		Gnomeo & Juliet	5.9	2011-01-13
# 4	0.009586617		Excalibur	6.7	1981-04-10
# 5	0.0093802195		Star Trek: Nemesis	6.3	2002-12-12
# 6	0.0093802195		Star Trek: Generations	6.5	1994-11-17
# 7	0.008384489		Conspiracy Theory	6.2	1997-08-07
# 8	0.008384489		The Wolverine	6.4	2013-07-25
# 9	0.008384489		Dune	6.5	1984-12-14
# 10	0.008384489		X-Men	6.5	2000-07-14
# 11	0.008384489		Robin Hood: Men in Tights	6.2	1993-07-28
# 12	0.0071982313		X-Men: Days of Future Past	7.7	2014-05-23
# 13	0.00718236		X2: X-Men United	6.5	2003-04-27
# 14	0.00718236		TMNT	6.0	2007-03-22
# 15	0.00718236		The Prince of Egypt	6.7	1998-12-15
# 16	0.00718236		X-Men: The Last Stand	6.1	2006-05-26
# 17	0.006091906		Ted	6.3	2012-06-29
# 18	0.0047915326		Chicken Little	5.4	2005-11-04
# 19	0.00057481206		Star Trek	7.3	2009-05-07
# 20	0.00045984966		Star Trek: The Motion Picture	6.0	1979-12-06

# %%
mappingSettings['movie']['properties'] \
               ['cast']['properties'] \
               ['name']['fields']['bigramed']['norms'] = {'enabled': False}
        
reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <200>
# Create TMDB Index <200>
# Indexing 3051 movies
# {
#  "poster_path": "/xYLmHi80zIlu3JDfJYfd1JY0Xl7.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 300400432,
#  "overview": "Col. Troutman recruits ex-Green Beret John Rambo for a highly secret and dangerous mission. Teamed with freedom fighter Co Bao, Rambo goes deep into Vietnam to rescue POWs. Deserted by his own team, he's left in a hostile jungle to fight for his life, avenge the death of a woman and bring corrupt officials to justice.",
#  "title_exact_match": "SENTINEL_BEGIN Rambo: First Blood Part II SENTINEL_END",
#  "video": false,
#  "id": 1369,
#  "genres": [
#   {
#    "id": 28,
#    "name": "Action"
#   },
#   {
#    "id": 12,
#    "name": "Adventure"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 53,
#    "name": "Thriller"
#   },
#   {
#    "id": 10752,
#    "name": "War"
#   }
#  ],
#  "title": "Rambo: First Blood Part II",
#  "tagline": "What most people call hell, he calls home.",
#  "vote_count": 224,
#  "homepage": "",
#  "belongs_to_collection": {
#   "poster_path": "/a61qhaM73Acotl98fAxj6ey7YzE.jpg",
#   "backdrop_path": "/Yt2ZxbJv2HM842B6FNMr59Vhyb.jpg",
#   "name": "Rambo Collection",
#   "id": 5039
#  },
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   },
#   {
#    "iso_639_1": "vi",
#    "name": "Ti\u1ebfng Vi\u1ec7t"
#   }
#  ],
#  "imdb_id": "tt0089880",
#  "adult": false,
#  "backdrop_path": "/dy5ThWXUuEHH60liT8oVSDqkSGB.jpg",
#  "production_companies": [
#   {
#    "name": "TriStar Pictures",
#    "id": 559
#   },
#   {
#    "name": "Carolco Pictures",
#    "id": 14723
#   }
#  ],
#  "release_date": "1985-05-21",
#  "popularity": 1.09210705984778,
#  "original_title": "Rambo: First Blood Part II",
#  "budget": 44000000,
#  "cast": [
#   {
#    "name": "Sylvester Stallone",
#    "character": "John J. Rambo",
#    "order": 0,
#    "cast_id": 27,
#    "credit_id": "52fe42f0c3a36847f802e327",
#    "profile_path": "/gnmwOa46C2TP35N7ARSzboTdx2u.jpg",
#    "id": 16483
#   },
#   {
#    "name": "Richard Crenna",
#    "character": "Col. Samuel Trautman",
#    "order": 1,
#    "cast_id": 28,
#    "credit_id": "52fe42f0c3a36847f802e32b",
#    "profile_path": "/fUCwfoN3JurrzltOyJT9rDNZRbV.jpg",
#    "id": 16554
#   },
#   {
#    "name": "Charles Napier",
#    "character": "Marshall Murdock",
#    "order": 2,
#    "cast_id": 29,
#    "credit_id": "52fe42f0c3a36847f802e32f",
#    "profile_path": "/hZ3bCBxnHc7Zvrm3Rt2CPgXSLLT.jpg",
#    "id": 16119
#   },
#   {
#    "name": "Steven Berkoff",
#    "character": "Lt. Col. Podovsky",
#    "order": 3,
#    "cast_id": 30,
#    "credit_id": "52fe42f0c3a36847f802e333",
#    "profile_path": "/jiYMK9prj46Qe4gmbKtBDE6YlSr.jpg",
#    "id": 782
#   },
#   {
#    "name": "Julia Nickson",
#    "character": "Co Bao",
#    "order": 4,
#    "cast_id": 31,
#    "credit_id": "52fe42f0c3a36847f802e337",
#    "profile_path": "/zQzqbbfixENqr2NLp92EOtL7POQ.jpg",
#    "id": 16578
#   },
#   {
#    "name": "George Cheung",
#    "character": "Capt Vinh",
#    "order": 5,
#    "cast_id": 32,
#    "credit_id": "52fe42f0c3a36847f802e33b",
#    "profile_path": null,
#    "id": 16580
#   },
#   {
#    "name": "Andy Wood",
#    "character": "Banks",
#    "order": 6,
#    "cast_id": 33,
#    "credit_id": "52fe42f0c3a36847f802e33f",
#    "profile_path": null,
#    "id": 16581
#   },
#   {
#    "name": "William Ghent",
#    "character": "Capt. Vinh",
#    "order": 7,
#    "cast_id": 34,
#    "credit_id": "52fe42f0c3a36847f802e343",
#    "profile_path": null,
#    "id": 16582
#   },
#   {
#    "name": "Voyo Goric",
#    "character": "Sgt. Yushin",
#    "order": 8,
#    "cast_id": 35,
#    "credit_id": "52fe42f0c3a36847f802e347",
#    "profile_path": null,
#    "id": 16583
#   },
#   {
#    "name": "Dana Lee",
#    "character": "Gunboat captain",
#    "order": 9,
#    "cast_id": 36,
#    "credit_id": "52fe42f0c3a36847f802e34b",
#    "profile_path": null,
#    "id": 16584
#   },
#   {
#    "name": "Baoan Coleman",
#    "character": "Gunboat captain II",
#    "order": 10,
#    "cast_id": 37,
#    "credit_id": "52fe42f0c3a36847f802e34f",
#    "profile_path": null,
#    "id": 16585
#   },
#   {
#    "name": "Steve Williams",
#    "character": "Lifer",
#    "order": 11,
#    "cast_id": 38,
#    "credit_id": "52fe42f0c3a36847f802e353",
#    "profile_path": null,
#    "id": 16586
#   },
#   {
#    "name": "Don Collins",
#    "character": "POW #1",
#    "order": 12,
#    "cast_id": 39,
#    "credit_id": "52fe42f0c3a36847f802e357",
#    "profile_path": null,
#    "id": 16587
#   },
#   {
#    "name": "Christopher Grant",
#    "character": "POW #2",
#    "order": 13,
#    "cast_id": 40,
#    "credit_id": "52fe42f0c3a36847f802e35b",
#    "profile_path": null,
#    "id": 16588
#   },
#   {
#    "name": "Martin Kove",
#    "character": "Ericson",
#    "order": 14,
#    "cast_id": 41,
#    "credit_id": "52fe42f0c3a36847f802e35f",
#    "profile_path": "/rQtB405GPPgWNL2EUL9mOx4FTb9.jpg",
#    "id": 56117
#   }
#  ],
#  "directors": [
#   {
#    "name": "George P. Cosmatos",
#    "credit_id": "52fe42efc3a36847f802e28d",
#    "job": "Director",
#    "department": "Directing",
#    "profile_path": "/6DIKPjnDvr7oHgTPHTXM5te45Qt.jpg",
#    "id": 16566
#   }
#  ],
#  "names_exact_match": [
#   "SENTINEL_BEGIN Sylvester Stallone SENTINEL_END",
#   "SENTINEL_BEGIN Richard Crenna SENTINEL_END",
#   "SENTINEL_BEGIN Charles Napier SENTINEL_END",
#   "SENTINEL_BEGIN Steven Berkoff SENTINEL_END",
#   "SENTINEL_BEGIN Julia Nickson SENTINEL_END",
#   "SENTINEL_BEGIN George Cheung SENTINEL_END",
#   "SENTINEL_BEGIN Andy Wood SENTINEL_END",
#   "SENTINEL_BEGIN William Ghent SENTINEL_END",
#   "SENTINEL_BEGIN Voyo Goric SENTINEL_END",
#   "SENTINEL_BEGIN Dana Lee SENTINEL_END",
#   "SENTINEL_BEGIN Baoan Coleman SENTINEL_END",
#   "SENTINEL_BEGIN Steve Williams SENTINEL_END",
#   "SENTINEL_BEGIN Don Collins SENTINEL_END",
#   "SENTINEL_BEGIN Christopher Grant SENTINEL_END",
#   "SENTINEL_BEGIN Martin Kove SENTINEL_END",
#   "SENTINEL_BEGIN George P. Cosmatos SENTINEL_END"
#  ],
#  "vote_average": 6.2,
#  "runtime": 96
# }
# Bulk Index into TMDB Index <200>

# %% [markdown]
# ### Rerunning with Norms Off For Bigrams

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'bool': {
            'disable_coord': True,
            'should': [
                {'match_phrase': {
                    'title_exact_match': {
                        'query': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END,
                        'boost': 1000,
                    }          
                }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'
                }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['directors.name.bigramed', 'cast.name.bigramed'],
                    'type': 'cross_fields',
                   'boost': 100
                 }}
                
            ]
        }
    },
    'size': 20,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.03920228		Star Trek: Insurrection	6.3	1998-12-10
# 2	0.03920228		Star Trek: First Contact	6.9	1996-11-21
# 3	0.03917096		Star Trek: Nemesis	6.3	2002-12-12
# 4	0.03917096		Star Trek: Generations	6.5	1994-11-17
# 5	0.03820324		Gnomeo & Juliet	5.9	2011-01-13
# 6	0.03820324		Excalibur	6.7	1981-04-10
# 7	0.03818829		X-Men: Days of Future Past	7.7	2014-05-23
# 8	0.038187582		Conspiracy Theory	6.2	1997-08-07
# 9	0.038187582		The Wolverine	6.4	2013-07-25
# 10	0.038187582		Dune	6.5	1984-12-14
# 11	0.038187582		X-Men	6.5	2000-07-14
# 12	0.038171925		X2: X-Men United	6.5	2003-04-27
# 13	0.038171925		TMNT	6.0	2007-03-22
# 14	0.038171925		The Prince of Egypt	6.7	1998-12-15
# 15	0.038171925		X-Men: The Last Stand	6.1	2006-05-26
# 16	0.03815442		Chicken Little	5.4	2005-11-04
# 17	0.00056567905		Star Trek	7.3	2009-05-07
# 18	0.0004525432		Star Trek: The Motion Picture	6.0	1979-12-06
# 19	0.0004525432		Star Trek Into Darkness	7.5	2013-05-16
# 20	0.0003959753		Star Trek VI: The Undiscovered Country	6.6	1991-12-05

# %% [markdown]
# # 7.4.4.1 Exact Name Matching Function Query Skeleton using TF*IDF (no listing number)

# %%
query = {
    'query': {
        'function_score': {
            'query': {
                'match_phrase': {
                    'names_exact_match': SENTINEL_BEGIN + ' william shatner ' + SENTINEL_END
                }
            },          
            'functions': [
               
            ]
        }        
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	1.9612461		Star Trek V: The Final Frontier	5.4	1989-06-09
# 2	1.733513		Showtime	5.3	2002-03-14
# 3	1.733513		Osmosis Jones	5.4	2001-08-07
# 4	1.3868104		Star Trek IV: The Voyage Home	6.7	1986-11-25
# 5	1.3868104		Star Trek II: The Wrath of Khan	7.1	1982-06-03
# 6	1.3868104		Miss Congeniality 2: Armed and Fabulous	5.3	2005-03-11
# 7	1.2134591		Over the Hedge	6.2	2006-04-22
# 8	1.2134591		Escape from Planet Earth	5.9	2013-02-14
# 9	1.2134591		Star Trek: The Motion Picture	6.0	1979-12-06
# 10	1.2134591		Star Trek III: The Search for Spock	6.3	1984-05-31

# %% [markdown]
# # 7.4.4.1 Exact Name Matching Function, Ignoring TF*IDF

# %%
query = {
    'query': {
        'function_score': {
            'query': {
                'constant_score': {
                    'filter': {
                        'match_phrase': {
                            'names_exact_match': SENTINEL_BEGIN + ' william shatner ' + SENTINEL_END
                        }
                    },
                    'boost': 1000.0
                }
            },          
            'functions': [
            ]
        }        
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	1000.0		Over the Hedge	6.2	2006-04-22
# 2	1000.0		Showtime	5.3	2002-03-14
# 3	1000.0		Escape from Planet Earth	5.9	2013-02-14
# 4	1000.0		Star Trek VI: The Undiscovered Country	6.6	1991-12-05
# 5	1000.0		Star Trek V: The Final Frontier	5.4	1989-06-09
# 6	1000.0		Star Trek IV: The Voyage Home	6.7	1986-11-25
# 7	1000.0		Star Trek: The Motion Picture	6.0	1979-12-06
# 8	1000.0		Star Trek II: The Wrath of Khan	7.1	1982-06-03
# 9	1000.0		Star Trek III: The Search for Spock	6.3	1984-05-31
# 10	1000.0		Miss Congeniality	6.0	2000-12-14

# %%
usersSearch='Star Trek Patrick Stewart'
query={
    'explain' : True,
    'query': {
        'bool': { 
            'should': [ 
                {
                  'multi_match': {
                   'query': usersSearch,
                    'fields': ['overview', 'title', 'directors.name', 'cast.name'],
                    'type': 'cross_fields'
                  }
                },
                {
                'multi_match': {
                'query': usersSearch,
                'fields': ['directors.name.bigrammed','cast.name.bigrammed'],
                'type': 'cross_fields',
                'boost': 100
                  }
                }
            ]
        }
    }
}
#mappingSettings['properties']['cast']['properties']['name']['fields']['bigramed']['norms'] = {'enabled': False}
#reindex(analysisSettings, mappingSettings, movieDict)
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	15.94338		Star Trek: Insurrection	6.3	1998-12-10
# 2	15.556217		Star Trek: Generations	6.5	1994-11-17
# 3	15.070194		Star Trek: Nemesis	6.3	2002-12-12
# 4	14.561464		Star Trek: First Contact	6.9	1996-11-21
# 5	10.458246		Star Trek	7.3	2009-05-07
# 6	8.9117155		Ted	6.3	2012-06-29
# 7	7.8453965		Star Trek Into Darkness	7.5	2013-05-16
# 8	7.548763		Flatliners	6.5	1990-08-09
# 9	7.197505		Dinosaur	6.2	2000-05-13
# 10	7.164365		Vertigo	7.4	1958-05-28

# %% [markdown]
# # 7.4.4.1, Listing 9 Turning User Rating into A Signal

# %%
query = {
    'query': {
        'function_score': {
            'query': {
                'match_all': {}
            },          
            'functions': [
            {
                 "field_value_factor": {
                 "field": "vote_average",
                 "modifier": "sqrt"
                }
            }]
        }        
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	2.9325757		Whiplash	8.6	2014-10-10
# 2	2.9154758		Feast	8.5	2014-11-07
# 3	2.8982754		Paperman	8.4	2012-11-02
# 4	2.8982754		Mommy	8.4	2014-09-19
# 5	2.8982754		Interstellar	8.4	2014-11-05
# 6	2.8982754		Avengers: Age of Ultron	8.4	2015-05-01
# 7	2.8809721		The Tale of the Princess Kaguya	8.3	2013-11-23
# 8	2.8809721		Presto	8.3	2008-06-26
# 9	2.8635643		The Shawshank Redemption	8.2	1994-09-14
# 10	2.8635643		Wolf Children	8.2	2012-08-29

# %% [markdown]
# # 7.4.4.2 Listing 10, Turning Recency of Release Into A Signal (first try)

# %%
query = {
    'query': {
        'function_score': {
            'query': {
                'match_all': {}
            },          
            'functions': [
            {
                 "gauss": {
                    "release_date": {
                        "origin": "now",
                        "scale": "900d",
                        "decay": 0.5
                    }
                }
            }]
        }        
    },
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.99437076		Resident Evil: Rising	6.1	2016-01-01
# 2	0.9773075		Avengers: Age of Ultron	8.4	2015-05-01
# 3	0.9690168		Furious 7	7.8	2015-04-03
# 4	0.9667524		Home	7.2	2015-03-27
# 5	0.9667524		It Follows	7.5	2015-03-27
# 6	0.96441245		Insurgent	7.3	2015-03-20
# 7	0.9619975		Frozen Fever	7.0	2015-03-13
# 8	0.9619975		Cinderella	7.3	2015-03-13
# 9	0.9595081		Chappie	7.0	2015-03-06
# 10	0.9569449		Jupiter Ascending	5.6	2015-02-27

# %% [markdown]
# # 7.4.4.2 Listing 10, Adjusted Gaussian Decay (set scale to 15 years)

# %%
query = {
    'query': {
        'function_score': {
            'query': {
                'match_all': {}
            },          
            'functions': [
            {
                 "gauss": {
                    "release_date": {
                        "origin": "now",
                        "scale": "5500d",
                        "decay": 0.5
                    }
                }
            }]
        }        
    },
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	0.99984884		Resident Evil: Rising	6.1	2016-01-01
# 2	0.99938554		Avengers: Age of Ultron	8.4	2015-05-01
# 3	0.9991576		Furious 7	7.8	2015-04-03
# 4	0.999095		Home	7.2	2015-03-27
# 5	0.999095		It Follows	7.5	2015-03-27
# 6	0.9990302		Insurgent	7.3	2015-03-20
# 7	0.9989631		Frozen Fever	7.0	2015-03-13
# 8	0.9989631		Cinderella	7.3	2015-03-13
# 9	0.9988938		Chappie	7.0	2015-03-06
# 10	0.9988223		Jupiter Ascending	5.6	2015-02-27

# %% [markdown]
# # 7.4.4.3 -- Complete Name Boost

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'function_score': {
            'query': {
                'constant_score': {
                    'filter': {
                        'match_phrase': {
                            'names_exact_match': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END
                        }
                    },
                    'boost': 1000.0
                }            
            },          
            'functions': [
            {
                 "gauss": {
                    "release_date": {
                        "origin": "now",
                        "scale": "5500d",
                        "decay": 0.5
                    }
                }
            },
            {
                "field_value_factor": {
                 "field": "vote_average",
                 "modifier": "sqrt"
                }
            }
            
            ]
        }        
    },
    'explain': True,
    'size': 20
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	2322.3013		X-Men: Days of Future Past	7.7	2014-05-23
# 2	2032.8279		The Wolverine	6.4	2013-07-25
# 3	1901.5889		Ted	6.3	2012-06-29
# 4	1679.2792		Gnomeo & Juliet	5.9	2011-01-13
# 5	1253.6843		TMNT	6.0	2007-03-22
# 6	1171.1167		X-Men: The Last Stand	6.1	2006-05-26
# 7	1043.9172		Chicken Little	5.4	2005-11-04
# 8	875.0317		X2: X-Men United	6.5	2003-04-27
# 9	825.2049		Star Trek: Nemesis	6.3	2002-12-12
# 10	621.5165		X-Men	6.5	2000-07-14
# 11	508.84805		The Prince of Egypt	6.7	1998-12-15
# 12	492.47284		Star Trek: Insurrection	6.3	1998-12-10
# 13	402.069		Conspiracy Theory	6.2	1997-08-07
# 14	380.95868		Star Trek: First Contact	6.9	1996-11-21
# 15	268.07132		Star Trek: Generations	6.5	1994-11-17
# 16	209.7008		Robin Hood: Men in Tights	6.2	1993-07-28
# 17	38.20945		Dune	6.5	1984-12-14
# 18	16.165955		Excalibur	6.7	1981-04-10

# %% [markdown]
# # Not Shown In Chapter: The Whole Shebang

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'bool': {
            'should': [
                {'match_phrase': {
                    'title_exact_match': {
                        'query': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END,
                        'boost': 1000,
                    }          
                }},
                {
                   'function_score': {
                        'query': {
                            'constant_score': {
                                'filter': {
                                    'match_phrase': {
                                        'names_exact_match': SENTINEL_BEGIN + ' ' + usersSearch + ' ' + SENTINEL_END
                                    }
                                },
                                'boost': 1000.0
                            }            
                        },          
                        'functions': [
                        {
                             "gauss": {
                                "release_date": {
                                    "origin": "now",
                                    "scale": "5500d",
                                    "decay": 0.5
                                }
                            }
                        },
                        {
                            "field_value_factor": {
                             "field": "vote_average",
                             "modifier": "sqrt"
                            }
                        }
                        
                        ]
                    }                    
                },
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['directors.name.bigramed','cast.name.bigramed'],
                    'type': 'cross_fields',
                    'boost': 100
                 }},
                {'multi_match': {
                   'query': usersSearch,  #User's query
                    'fields': ['overview', 'title', #C
                               'directors.name', 'cast.name'],
                    'type': 'cross_fields'                                
                 }},
                
            ]
        }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	2328.771		X-Men: Days of Future Past	7.7	2014-05-23
# 2	2038.7957		The Wolverine	6.4	2013-07-25
# 3	1907.2021		Ted	6.3	2012-06-29
# 4	1685.8298		Gnomeo & Juliet	5.9	2011-01-13
# 5	1259.2784		TMNT	6.0	2007-03-22
